# %% [markdown]
# Ari Kaminski Lab 3
# Problem 1

# %% [markdown]
# My rock paper scissor variant is rock paper scissors shoes and foot
#
# Paper beats rock, rock beats scissor, scissor beats paper
#
# Shoe beats rock, shoe loses foot, shoe loses paper, shoe beats scissors
#
# foot beats paper, foot beats shoe, foot loses scissors, foot loses rock

# %%
#This is a program for my rock paper scissors shoes and foot- Ari Kaminski
import random

player = input("Enter your choice of rock, paper, scissor, foot, shoe = ")
computer = random.choice(['rock', 'paper', 'scissor', 'foot', 'shoe'])


print("Computer has chosen = " + computer)

if player == computer:
    print("Its a tie")
elif player == 'rock' and computer == 'paper':
    print("Computer wins")
elif player == 'rock' and computer == 'shoe':
    print("Computer wins")
elif player == 'rock' and computer == 'scissor':
    print("Computer wins")
elif player == 'rock' and computer == 'foot':
    print("Player wins")
elif player == 'paper' and computer == 'shoe':
    print("Player wins")
elif player == 'paper' and computer == 'rock':
    print("Player wins")
elif player == 'paper' and computer == 'scissor':
    print("Computer wins")    
elif player == 'paper' and computer == 'foot':
    print("Computer wins")
elif player == 'scissor' and computer == 'rock':
    print("computer wins")
elif player == 'scissor' and computer == 'paper':
    print("Player wins")
elif player == 'scissor' and computer == 'foot':
    print("Player wins")
elif player == 'scissor' and computer == 'shoe':
    print("computer wins")
elif player == 'shoe' and computer == 'rock':
    print("Player wins")
elif player == 'shoe' and computer == 'paper':
    print("Computer wins")
elif player == 'shoe' and computer == 'scissor':
    print("Player wins")
elif player == 'shoe' and computer == 'foot':
    print("Computer wins")
elif player == 'foot' and computer == 'rock':
    print("Computer wins")
elif player == 'foot' and computer == 'paper':
    print("Player wins")
elif player == 'foot' and computer == 'scissor':
    print("Computer wins")
elif player == 'foot' and computer == 'shoe':
    print("Player wins")
else:
    print("Error")
# Out:
# Enter your choice of rock, paper, scissor, foot, shoe = f
# Computer has chosen = rock
# Error

# %% [markdown]
# Lab 3 problem 2

# %%
#This is code for rock paper scissor foot shoes but with nested if statements

import random

player = input("Enter your choice of rock, paper, scissor, foot, shoe = ")
computer = random.choice(['rock', 'paper', 'scissor', 'foot', 'shoe'])


print("Computer has chosen = " + computer)

if(player == computer):
    print("It is a tie")
elif(player == 'rock'):
    if(computer == 'paper'):
        print("computer wins")
    elif(computer == 'scissor'):
        print("player wins")
    elif(computer == 'foot'):
        print("player wins")
    elif(computer == 'shoe'):
        print("computer wins")
elif(player == 'paper'):
    if(computer == 'rock'):
        print("player wins")
    elif(computer == 'scissor'):
        print("computer wins")
    elif(computer == 'foot'):
        print("computer wins")
    elif(computer == 'shoe'):
        print("player wins")
elif(player == 'scissor'):
    if(computer == 'rock'):
        print("computer wins")
    elif(computer == 'paper'):
        print("player wins")
    elif(computer == 'foot'):
        print("player wins")
    elif(computer == 'shoe'):
        print("computer wins")
elif(player == 'shoe'):
    if(computer == 'rock'):
        print("player wins")
    elif(computer == 'scissor'):
        print("player wins")
    elif(computer == 'foot'):
        print("computer wins")
    elif(computer == 'paper'):
        print("computer wins")
elif(player == 'foot'):
    if(computer == 'rock'):
        print("computer wins")
    elif(computer == 'scissor'):
        print("computer wins")
    elif(computer == 'paper'):
        print("player wins")
    elif(computer == 'shoe'):
        print("player wins")
# Out:
# Enter your choice of rock, paper, scissor, foot, shoe = rock
# Computer has chosen = shoe
# computer wins

# %% [markdown]
# Lab 3 problem 3

# %%
#This is code for a create your own adventure(cooking) story

protein = input("Choose a protein, 1 for chicken, 2 for beef, 3 for pork = ")

if (protein == '1'):
    veg = input("You have chosen chicken, what veggies would you like? 1 for carrots, 2 for potatoes, 3 for green beans =")
    if (veg == '1'):
        print("You are having chicken and carrots for dinner")
        des = input("What would you like for dessert? 1 for ice cream, 2 for jello =")
        if(des == '1'):
            print("Dinner is done, time for ice cream!")
        elif(des == '2'):
            print("Dinner is done, time for jello!") 
    elif(veg == '2'):
        print("You are having chicken and potatoes for dinner")
        des = input("What would you like for dessert? 1 for ice cream, 2 for jello =")
        if(des == '1'):
            print("Dinner is done, time for ice cream!")
        elif(des == '2'):
            print("Dinner is done, time for jello!") 
    elif(veg == '3'):
        print("you are having chicken and green beans for dinner")
        des = input("What would you like for dessert? 1 for ice cream, 2 for jello =")
        if(des == '1'):
            print("Dinner is done, time for ice cream!")
        elif(des == '2'):
            print("Dinner is done, time for jello!")
elif (protein == '2'):
    veg = input("You have chosen beef, what veggies would you like? 1 for carrots, 2 for potatoes, 3 for green beans =")
    if (veg == '1'):
        print("You are having beef and carrots for dinner")
        des = input("What would you like for dessert? 1 for ice cream, 2 for jello =")
        if(des == '1'):
            print("Dinner is done, time for ice cream!")
        elif(des == '2'):
            print("Dinner is done, time for jello!") 
    elif(veg == '2'):
        print("You are having beef and potatoes for dinner")
        des = input("What would you like for dessert? 1 for ice cream, 2 for jello =")
        if(des == '1'):
            print("Dinner is done, time for ice cream!")
        elif(des == '2'):
            print("Dinner is done, time for jello!") 
    elif(veg == '3'):
        print("you are having beef and green beans for dinner")
        des = input("What would you like for dessert? 1 for ice cream, 2 for jello =")
        if(des == '1'):
            print("Dinner is done, time for ice cream!")
        elif(des == '2'):
            print("Dinner is done, time for jello!") 
elif (protein == '3'):
    veg = input("You have chosen pork, what veggies would you like? 1 for carrots, 2 for potatoes, 3 for green beans =")
    if (veg == '1'):
        print("You are having pork and carrots for dinner")
        des = input("What would you like for dessert? 1 for ice cream, 2 for jello =")
        if(des == '1'):
            print("Dinner is done, time for ice cream!")
        elif(des == '2'):
            print("Dinner is done, time for jello!") 
    elif(veg == '2'):
        print("You are having pork and potatoes for dinner")
        des = input("What would you like for dessert? 1 for ice cream, 2 for jello =")
        if(des == '1'): 
            print("Dinner is done, time for ice cream!")
        elif(des == '2'):
            print("Dinner is done, time for jello!") 
    elif(veg == '3'):
        print("you are having pork and green beans for dinner")
        des = input("What would you like for dessert? 1 for ice cream, 2 for jello =")
        if(des == '1'):
            print("Dinner is done, time for ice cream!")
        elif(des == '2'):
            print("Dinner is done, time for jello!")
# Out:
# Choose a protein, 1 for chicken, 2 for beef, 3 for pork = 2
# You have chosen beef, what veggies would you like? 1 for carrots, 2 for potatoes, 3 for green beans =1
# You are having beef and carrots for dinner
# What would you like for dessert? 1 for ice cream, 2 for jello =2
# Dinner is done, time for jello!
