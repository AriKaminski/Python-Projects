# %% [markdown]
# Ari Kaminski
#
#
# Lab 6 Problem 1

# %%
#Ari Kaminski
#This is code for a contact list book

def display_menu():
    print("MENU")
    print("list - List all contacts")
    print("view - View a contact")
    print("add - Add a contact")
    print("del - Delete a contact")
    print("exit - exit program")
    
def list(contacts_list):
    if len(contacts_list) == 0:
        print("There are no contacts in the list.\n")
    else:
        i = 1
        print()
        for row in contacts_list:
            print(str(i) + ". " + row[0])
            i += 1
        
        print()
        
        
"""The add funtion adds a contact to the contact list, contact is added at the 0 posistion"""
        
def add(contacts_list):
    name = input("Contact Name: ")
    email = input("Contact Email: ")
    number = input("Contact Phone Number")
    contact = []
    contact.append(name)
    contact.append(email)
    contact.append(number)
    contacts_list.append(contact)
    print(contact[0] + " was added to the contact list.\n")
    
"""The view function views all information about a given contact. The posistion of the contact is input by the user"""
    
def view(contacts_list):
    number = int(input("Contact number posistion: "))
    if number < 1 or number > len(contacts_list):
        print("Invalid contact number.\n")
    else:
        contacty = contacts_list.pop(number - 1)
        print("Name )" + contacty[0])
        print("Email )" + contacty[1])
        print("Phone )" + contacty[2])
        print("\n")

        
"""The delete function removes a contact from the list. The posistion of the contact to be deleted is input by the user"""
    
def delete(contacts_list):
    number = int(input("Contact number posistion: "))
    if number < 1 or number > len(contacts_list):
        print("Invalid contact number.\n")
    else:
        contacts = contacts_list.pop(number-1)
        print(contacts[0] + " was deleted from the contact list.\n")

        
"""The main function is what is run"""
              
def main():
    contacts_list = [["Linda Yang", "yang@rvcc.net", "101 1010 1010"],
                     ["Michele VanBuren", "michele@verizon.net", "44 20 7946 0958"]]
    
    display_menu()
    command = input("Enter input: ")
        
    while (command.lower() != "exit"):
        
        if command.lower() == "list":
            list(contacts_list)
            display_menu()
        elif command.lower() == "view":
            view(contacts_list)
            display_menu()
        elif command.lower() == "add":
            add(contacts_list)
            display_menu()
        elif command.lower() == "del":
            delete(contacts_list)
            display_menu()
        else:
            print("Not a valid input. \n")

        command = input("Enter input: \n" )
         
    print("Program finished")     
        
if __name__ == "__main__":
    main()
# Out:
# MENU
# list - List all contacts
# view - View a contact
# add - Add a contact
# del - Delete a contact
# exit - exit program
# Enter input: list
#
# 1. Linda Yang
# 2. Michele VanBuren
#
# MENU
# list - List all contacts
# view - View a contact
# add - Add a contact
# del - Delete a contact
# exit - exit program
# Enter input:
# view
# Contact number posistion: 2
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-5472da1735cc> in <module>
#      91
#      92 if __name__ == "__main__":
# ---> 93     main()
#
# <ipython-input-4-5472da1735cc> in main()
#      75             display_menu()
#      76         elif command.lower() == "view":
# ---> 77             view(contacts_list)
#      78             display_menu()
#      79         elif command.lower() == "add":
#
# <ipython-input-4-5472da1735cc> in view(contacts_list)
#      43         print("Invalid contact number.\n")
#      44     else:
# ---> 45         contacty = contacts_list()
#      46         print("Name )" + contacty[0])
#      47         print("Email )" + contacty[1])
#
# TypeError: 'list' object is not callable
